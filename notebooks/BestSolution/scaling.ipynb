# %%
import numpy as np

# Load uploaded file
best_preds = np.load('/kaggle/input/datasets/brijeshwarreddys/preds-npy/ensemble_c_b.npy')
print("Shape:", best_preds.shape)
print("Range:", best_preds.min(), best_preds.max())

# Change this value each time!
scale = 0.95

scaled = np.clip(best_preds * scale, 0, None)
np.save('preds_scaled.npy', scaled)
print(f"Saved! Scale={scale} | Range: [{scaled.min():.2f}, {scaled.max():.2f}]")
# Out:
# Shape: (218, 140, 124, 16)
# Range: 0.0 781.0815
# Saved! Scale=0.95 | Range: [0.00, 742.03]
